# %%
def Hanoi(n , a, b, c,):
  if(n==1):
    print ("Hanoi Tower move", a, "-->", c)
  else:
    Hanoi(n-1, a, c, b)
    Hanoi(1, a, b, c)
    Hanoi(n-1, b, a, c)

# %%
n=int(input("請輸入數字:"))
a="一號柱"
b="二號柱"
c="三號柱"
Hanoi(n,a,b,c)
# Out:
# 請輸入數字:4
# Hanoi Tower move 一號柱 --> 二號柱
# Hanoi Tower move 一號柱 --> 三號柱
# Hanoi Tower move 二號柱 --> 三號柱
# Hanoi Tower move 一號柱 --> 二號柱
# Hanoi Tower move 三號柱 --> 一號柱
# Hanoi Tower move 三號柱 --> 二號柱
# Hanoi Tower move 一號柱 --> 二號柱
# Hanoi Tower move 一號柱 --> 三號柱
# Hanoi Tower move 二號柱 --> 三號柱
# Hanoi Tower move 二號柱 --> 一號柱
# Hanoi Tower move 三號柱 --> 一號柱
# Hanoi Tower move 二號柱 --> 三號柱
# Hanoi Tower move 一號柱 --> 二號柱
# Hanoi Tower move 一號柱 --> 三號柱
# Hanoi Tower move 二號柱 --> 三號柱

# %%
a= int(2)
b= int(3)
print("%d"%(a+b))
# Out:
# 5
